# %%
import pandas as pd
import numpy as np

# %%
p1 = pd.read_csv("pitch1_Sports2D_px_person00.trc")

# %%
from io import StringIO

# %%
data_frames = [pd.read_csv(StringIO(p1.iloc[i, 0]), sep="\t", header=None) for i in range(p1.shape[0])]

# Now concatenate all DataFrames into one
data_parsed = pd.concat(data_frames, ignore_index=True)

# %%
data_parsed
# Out:
#            0           1           2           3      4             5   \
# 0    DataRate  CameraRate   NumFrames  NumMarkers  Units  OrigDataRate
# 1        30.0        30.0         110          22      m          30.0
# 2      Frame#        Time         Hip         NaN    NaN          RHip
# 3         NaN         NaN          X1          Y1     Z1            X2
# 4           0         0.0  395.350546  354.816732    0.0    356.792224
# ..        ...         ...         ...         ...    ...           ...
# 109       105         3.5  878.336697  397.772493    0.0    905.143076
# 110       106    3.533333  878.884744  403.848756    0.0    904.928195
# 111       107    3.566667   880.16692  404.075792    0.0    906.043815
# 112       108         3.6  881.889766  397.311903    0.0    907.728148
# 113       109    3.633333   883.95659  385.598449    0.0    909.744265
#
#                      6              7           8           9   ...   58  \
# ...
