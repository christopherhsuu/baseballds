# %%
pip install sports2d
# Out:
# ...
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.9 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.9 MB 2.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/3.9 MB 2.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.6/3.9 MB 2.0 MB/s eta 0:00:02
#    ------------------ --------------------- 1.8/3.9 MB 2.0 MB/s eta 0:00:02
#    ------------------------ --------------- 2.4/3.9 MB 2.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.9/3.9 MB 2.0 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.9 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 3.7/3.9 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/22.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/22.6 MB ? eta -:--:--
# ...

# %%
from Sports2D import Sports2D

# %%
Sports2D.process('C:\Users\chris\Desktop\pitching1.MOV')
# Out:
#   Cell In[7], line 1
#     Sports2D.process('C:\Users\chris\Desktop\pitching1.MOV')
#                                                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
from IPython.display import HTML

# %%
HTML("""
<video width="500" height="300" controls>
    <video src="file:///C:/Users/chris/Documents/GitHub/baseballds/pitch1_Sports2D.mp4" type="video/mp4">
</video/>
""")
# Out:
# <video width="500" height="300" controls>
#     <video src="file:///C:/Users/chris/Documents/GitHub/baseballds/pitch1_Sports2D.mp4" type="video/mp4">
# </video/>

# %%
<video src="C:/Users/chris/Documents/GitHub/baseballds/pitch1_Sports2D.mp4" type="video/mp4">
</video>
# Out:
#   Cell In[39], line 1
#     <video src="C:/Users/chris/Documents/GitHub/baseballds/pitch1_Sports2D.mp4" type="video/mp4">
#     ^
# SyntaxError: invalid syntax
